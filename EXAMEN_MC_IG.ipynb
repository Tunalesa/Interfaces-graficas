# %% [markdown]
# <a href="https://colab.research.google.com/github/Tunalesa/Interfaces-graficas/blob/main/EXAMEN_MC_IG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Maria de los Angeles Tunales Lopez 2077818 IMTC
#
# EXAMEN MEDIO CURSO INTERFACES GRAFICAS

# %% [markdown]
# Formulas a utilizar
#
#
#  ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %%
#inicio del programa
#primero vamosa ingresar nuestro conjunto de datos a calcular
X1=[160,591,114,229,230,270,128,1657,624,1503]
X2=[15.0,69.9,6.5,22.4,28.4,65.9,19.4,198.7,38.8,138.2]

#vamos a definir una primera variable para x1 y hacer los calculos sobre ella
def A (X1): #aqui se define como A1 para el conjunto de datos de X1

    desviacion_X1= statistics.stdev(X1) #calcular la desvación estandar y el resultado la definimos en la variable "desviacion_X1"
    media_X1=sum(X1)/len(X1) #se calcula la media mediante la formula asignada y se establece como "media_X1"
    return desviacion_X1,media_X1

#se establece nuevamente las mismas operaciones pero para esta ocacion para la columna 2
def B (X2):
    desviacion_X2 = statistics.stdev(X2)
    media2=sum(X2)/len(X2)
    return desviacion_X2,media2

#se imprimen los datos obtenidos en nuestro programa

print("la media de la columna#1 es: ", media_X1)
print("Desviación estandar de la columna#1 es: ", desviacion_X1)
print("la media de la columna#2 es: ", media2)
print("Desviación estandar de la columna#2 es: ", desviacion_X2)

#fin del programa
# Out:
# la media de la columna#1 es:  550.6
# Desviación estandar de la columna#1 es:  572.0268447469149
# la media de la columna#2 es:  60.32000000000001
# Desviación estandar de la columna#2 es:  62.25583060601187
